# %%
import pandas as pd

# %%
emp = pd.read_excel(r"C:\Users\vamsi\Downloads\Rawdata.xlsx")

# %%
emp
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       4 non-null      object
#  3   Location  4 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       5 non-null      object
# dtypes: object(6)
# memory usage: 420.0+ bytes

# %%
emp.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
emp[['Name','Domain','Location']]
# Out:
#      Name          Domain   Location
# 0    Mike   Datascience#$     Mumbai
# 1  Teddy^         Testing  Bangalore
# 2   Uma#r  Dataanalyst^^#        NaN
# 3    Jane     Ana^^lytics   Hyderbad
# 4  Uttam*      Statistics        NaN
# 5     Kim             NLP      Delhi

# %%
emp['Name'] =  emp['Name'].str.replace(r'\W', '',regex=True)
emp['Domain'] =  emp['Domain'].str.replace(r'\W', '',regex=True)
emp['Location'] =  emp['Location'].str.replace(r'\W', '',regex=True)

# %%
emp[['Name','Domain','Location']]
# Out:
#     Name       Domain   Location
# 0   Mike  Datascience     Mumbai
# 1  Teddy      Testing  Bangalore
# 2   Umar  Dataanalyst        NaN
# 3   Jane    Analytics   Hyderbad
# 4  Uttam   Statistics        NaN
# 5    Kim          NLP      Delhi

# %%
emp[['Age','Salary','Exp']]
# Out:
#         Age   Salary      Exp
# 0  34 years   5^00#0       2+
# 1    45' yr  10%%000       <3
# 2       NaN  1$5%000   4> yrs
# 3       NaN   2000^0      NaN
# 4     67-yr   30000-  5+ year
# 5      55yr  6000^$0      10+

# %%
emp['Age'] = emp['Age'].str.extract(r'(\d+)')
emp['Salary'] = emp['Salary'].str.extract(r'(\d+)')
emp['Exp'] = emp['Exp'].str.extract(r'(\d+)')

# %%
emp[['Age','Salary','Exp']]
# Out:
#    Age Salary  Exp
# 0   34      5    2
# 1   45     10    3
# 2  NaN      1    4
# 3  NaN   2000  NaN
# 4   67  30000    5
# 5   55   6000   10

# %%
clean_data = emp.copy()

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai      5    2
# 1  Teddy      Testing   45  Bangalore     10    3
# 2   Umar  Dataanalyst  NaN        NaN      1    4
# 3   Jane    Analytics  NaN   Hyderbad   2000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi   6000   10

# %%
import numpy as np

# %%
clean_data['Age'] = clean_data['Age'].fillna(np.mean(pd.to_numeric(clean_data['Age'])))
clean_data['Exp'] = clean_data['Exp'].fillna(np.mean(pd.to_numeric(clean_data['Exp'])))

# %%
clean_data
# Out:
#     Name       Domain    Age   Location Salary  Exp
# 0   Mike  Datascience     34     Mumbai      5    2
# 1  Teddy      Testing     45  Bangalore     10    3
# 2   Umar  Dataanalyst  50.25        NaN      1    4
# 3   Jane    Analytics  50.25   Hyderbad   2000  4.8
# 4  Uttam   Statistics     67        NaN  30000    5
# 5    Kim          NLP     55      Delhi   6000   10

# %%
clean_data['Location'] = clean_data['Location'].fillna(clean_data['Location'].mode()[0])

# %%
clean_data
# Out:
#     Name       Domain    Age   Location Salary  Exp
# 0   Mike  Datascience     34     Mumbai      5    2
# 1  Teddy      Testing     45  Bangalore     10    3
# 2   Umar  Dataanalyst  50.25  Bangalore      1    4
# 3   Jane    Analytics  50.25   Hyderbad   2000  4.8
# 4  Uttam   Statistics     67  Bangalore  30000    5
# 5    Kim          NLP     55      Delhi   6000   10

# %%
 clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       6 non-null      object
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       6 non-null      object
# dtypes: object(6)
# memory usage: 420.0+ bytes

# %%
clean_data['Age'] = clean_data['Age'].astype(int)
clean_data['Salary'] = clean_data['Salary'].astype(int)
clean_data['Exp'] = clean_data['Exp'].astype(int)

clean_data['Name'] = clean_data['Name'].astype('category')
clean_data['Location'] = clean_data['Location'].astype('category')
clean_data['Domain'] = clean_data['Domain'].astype('category')

# %%
 clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      category
#  1   Domain    6 non-null      category
#  2   Age       6 non-null      int32
#  3   Location  6 non-null      category
#  4   Salary    6 non-null      int32
#  5   Exp       6 non-null      int32
# dtypes: category(3), int32(3)
# memory usage: 866.0 bytes

# %%
# next step is i will create an excel sheet for clean data

# %%
clean_data.to_csv('clean_data_new.csv')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\vamsi\\OneDrive\\Documents'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
clean_data
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai       5    2
# 1  Teddy      Testing   45  Bangalore      10    3
# 2   Umar  Dataanalyst   50  Bangalore       1    4
# 3   Jane    Analytics   50   Hyderbad    2000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi    6000   10

# %%
clean_data['Salary']
# Out:
# 0        5
# 1       10
# 2        1
# 3     2000
# 4    30000
# 5     6000
# Name: Salary, dtype: int32

# %%
vis1 = sns.distplot(clean_data['Salary']) # Univariant analyisis

# %%
vis2 = plt.hist(clean_data['Salary'])  # Univariant analyisis

# %%
vis3 = sns.lmplot(data= clean_data, x='Exp', y='Salary') #Bi variant Analysis we can detect outliers here

# %%
vis3 = sns.lmplot(data= clean_data, x='Exp', y='Salary', fit_reg = False)  # regression line absent

# %%
clean_data[:]
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai       5    2
# 1  Teddy      Testing   45  Bangalore      10    3
# 2   Umar  Dataanalyst   50  Bangalore       1    4
# 3   Jane    Analytics   50   Hyderbad    2000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi    6000   10

# %%
clean_data[:2]
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai       5    2
# 1  Teddy      Testing   45  Bangalore      10    3

# %%
clean_data[2:]
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 2   Umar  Dataanalyst   50  Bangalore       1    4
# 3   Jane    Analytics   50   Hyderbad    2000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi    6000   10

# %%
x_iv = clean_data.drop(['Salary'], axis=1)

# %%
x_iv
# Out:
#     Name       Domain  Age   Location  Exp
# 0   Mike  Datascience   34     Mumbai    2
# 1  Teddy      Testing   45  Bangalore    3
# 2   Umar  Dataanalyst   50  Bangalore    4
# 3   Jane    Analytics   50   Hyderbad    4
# 4  Uttam   Statistics   67  Bangalore    5
# 5    Kim          NLP   55      Delhi   10

# %%
x_iv.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Exp'], dtype='object')

# %%
y_iv = clean_data.drop(['Name', 'Domain', 'Age', 'Location', 'Exp'], axis=1)

# %%
y_iv
# Out:
#    Salary
# 0       5
# 1      10
# 2       1
# 3    2000
# 4   30000
# 5    6000

# %%
#VARIABLE TRANSFOEMATION

# %%
imputation = pd.get_dummies(clean_data)

# %%
imputation
# Out:
#    Age  Salary  Exp  Name_Jane  Name_Kim  Name_Mike  Name_Teddy  Name_Umar  \
# 0   34       5    2      False     False       True       False      False
# 1   45      10    3      False     False      False        True      False
# 2   50       1    4      False     False      False       False       True
# 3   50    2000    4       True     False      False       False      False
# 4   67   30000    5      False     False      False       False      False
# 5   55    6000   10      False      True      False       False      False
#
#    Name_Uttam  Domain_Analytics  Domain_Dataanalyst  Domain_Datascience  \
# 0       False             False               False                True
# 1       False             False               False               False
# 2       False             False                True               False
# 3       False              True               False               False
# 4        True             False               False               False
# ...
